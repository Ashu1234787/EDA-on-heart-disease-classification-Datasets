# %% [markdown]
# Load the CSV data: Use the Pandas library to load the CSV file into a DataFrame

# %%
#import important libraries
import pandas as pd
import numpy as np

# %%
# read the csv
url ="https://raw.githubusercontent.com/Ashu1234787/EDA-on-heart-disease-classification-Datasets/main/heart.csv"
data = pd.read_csv(url)

# %%
print(data)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # Data exploration: Explore and understand the characteristics of the data,like its shape, columns, data types,and basic statistics.

# %%
col=data.columns
print(col)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# print the shape of the DataFrame, so we can see how many examples we have
print( 'Shape of DataFrame: {}'.format(data.shape))
# Out:
# Shape of DataFrame: (1025, 14)

# %%
len(data)
# Out:
# 1025

# %%
dt=data.dtypes
print(dt)
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
print(data.head(1))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
#
#    ca  thal  target
# 0   2     3       0

# %%
print(data.head(2))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0

# %%
print (data.loc[1])
# Out:
# age          53.0
# sex           1.0
# cp            0.0
# trestbps    140.0
# chol        203.0
# fbs           1.0
# restecg       0.0
# thalach     155.0
# exang         1.0
# oldpeak       3.1
# slope         0.0
# ca            0.0
# thal          3.0
# target        0.0
# Name: 1, dtype: float64

# %%
print(data.tail())
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
print(data.head(10))
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
print(data.describe())
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# None

# %% [markdown]
# # Data cleaning: Clean the data by handling missing values, removing duplicates, and converting data types.

# %%
   print(data.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print(data.dropna())
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
   dro=data.drop_duplicates()
print(dro)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %% [markdown]
# # Feature encoding: Encode any categorical variables using one-hot encoding or label encoding.

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
#One-hot encoding

# %%
   encoder = OneHotEncoder()
   one_hot_encoded_data = encoder.fit_transform(data['sex'].values.reshape(-1,1))

# %%
   encoder = OneHotEncoder()
   one_hot_encoded_data = encoder.fit_transform(data['cp'].values.reshape(-1,1))

# %%
   # Label encoding

# %%
   encoder = LabelEncoder()
   data['sex'] = encoder.fit_transform(data['target'])

# %%
data.astype({'sex':'float64'})
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52  0.0   0       125   212    0        1      168      0      1.0
# 1      53  0.0   0       140   203    1        0      155      1      3.1
# 2      70  0.0   0       145   174    0        1      125      1      2.6
# 3      61  0.0   0       148   203    0        1      161      0      0.0
# 4      62  0.0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59  1.0   1       140   221    0        1      164      1      0.0
# 1021   60  0.0   0       125   258    0        0      141      1      2.8
# 1022   47  0.0   0       110   275    0        0      118      1      1.0
# 1023   50  1.0   0       110   254    0        0      159      0      0.0
# 1024   54  0.0   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # Data transformation: Apply transformations to columns or create new columns by combining or aggregating existing columns.

# %%
data['disease'] = data['sex'] + data['age']

# %%
print(data)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    0   0       125   212    0        1      168      0      1.0
# 1      53    0   0       140   203    1        0      155      1      3.1
# 2      70    0   0       145   174    0        1      125      1      2.6
# 3      61    0   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    0   0       125   258    0        0      141      1      2.8
# 1022   47    0   0       110   275    0        0      118      1      1.0
# 1023   50    1   0       110   254    0        0      159      0      0.0
# 1024   54    0   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  disease
# 0         2   2     3       0       52
# ...

# %%
data['normalized_column'] = (data['age'] - data['sex'].min()) / (data['age'].max() - data['sex'].min())

# %%
print(data)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    0   0       125   212    0        1      168      0      1.0
# 1      53    0   0       140   203    1        0      155      1      3.1
# 2      70    0   0       145   174    0        1      125      1      2.6
# 3      61    0   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    0   0       125   258    0        0      141      1      2.8
# 1022   47    0   0       110   275    0        0      118      1      1.0
# 1023   50    1   0       110   254    0        0      159      0      0.0
# 1024   54    0   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  disease  normalized_column
# ...

# %%
data.groupby('age').agg({'chol': 'mean'})
# Out:
#            chol
# age
# 29   204.000000
# 34   196.000000
# 35   209.200000
# 37   232.500000
# 38   193.666667
# 39   236.857143
# 40   196.090909
# 41   218.156250
# 42   246.807692
# 43   256.923077
# 44   220.000000
# 45   246.840000
# 46   234.608696
# 47   248.166667
# 48   250.130435
# 49   221.529412
# 50   227.000000
# 51   257.948718
# 52   226.348837
# 53   234.192308
# 54   253.905660
# 55   282.266667
# 56   258.871795
# 57   241.877193
# 58   253.794118
# 59   238.282609
# 60   245.189189
# 61   243.774194
# 62   256.486486
# 63   263.093750
# 64   274.970588
# 65   276.185185
# 66   244.240000
# 67   280.870968
# 68   238.750000
# 69   242.333333
# 70   251.857143
# 71   232.909091
# 74   269.000000
# 76   197.000000
# 77   304.000000

# %%
print(data)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    0   0       125   212    0        1      168      0      1.0
# 1      53    0   0       140   203    1        0      155      1      3.1
# 2      70    0   0       145   174    0        1      125      1      2.6
# 3      61    0   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    0   0       125   258    0        0      141      1      2.8
# 1022   47    0   0       110   275    0        0      118      1      1.0
# 1023   50    1   0       110   254    0        0      159      0      0.0
# 1024   54    0   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  disease  normalized_column
# ...

# %% [markdown]
# # Data visualization: Create visualizations to explore patterns and relationships in the data, using libraries like matplotlib and seaborn.

# %%
   import matplotlib.pyplot as plt
   import seaborn as sns

# %%
   plt.hist(data['cp'])
# Out:
# (array([497.,   0.,   0., 167.,   0.,   0., 284.,   0.,   0.,  77.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
data['target'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
plt.scatter(data['cp'], data['target'])

# %%
dbox=data.boxplot(column=['target'])

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Feature selection: Select the most relevant features for data analysis tasks like classification or clustering

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
  X = data.drop('target', axis=1)
y = data['target']

selector = SelectKBest(score_func=chi2, k=5)
selector.fit(X, y)
X_new = selector.transform(X)

# %%
selected_columns = ['sex', 'age','chol','cp','trestbps','slope']
data = data[selected_columns]

# %%
print(data)
# Out:
#       sex  age  chol  cp  trestbps  slope
# 0       0   52   212   0       125      2
# 1       0   53   203   0       140      0
# 2       0   70   174   0       145      0
# 3       0   61   203   0       148      2
# 4       0   62   294   0       138      1
# ...   ...  ...   ...  ..       ...    ...
# 1020    1   59   221   1       140      2
# 1021    0   60   258   0       125      1
# 1022    0   47   275   0       110      1
# 1023    1   50   254   0       110      2
# 1024    0   54   188   0       120      1
#
# [1025 rows x 6 columns]

# %%
data.shape
# Out:
# (1025, 6)

# %% [markdown]
# # Splitting the dataset: Divide the dataset into training and testing sets for validating the performance of ml algorithms.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
  X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42)

# %%
   model = LogisticRegression()
   model.fit(X_train, y_train)
   y_pred = model.predict(X_test)
   accuracy = accuracy_score(y_test, y_pred)

# %% [markdown]
# #  Model evaluation: Evaluate the performance of the built models using metrics like accuracy, precision, recall, F1-score, etc.

# %%
   from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
   print(classification_report(y_test, y_pred))
   print(confusion_matrix(y_test, y_pred))
   print(roc_auc_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       102
#            1       1.00      1.00      1.00       103
#
#     accuracy                           1.00       205
#    macro avg       1.00      1.00      1.00       205
# weighted avg       1.00      1.00      1.00       205
#
# [[102   0]
#  [  0 103]]
# 1.0
